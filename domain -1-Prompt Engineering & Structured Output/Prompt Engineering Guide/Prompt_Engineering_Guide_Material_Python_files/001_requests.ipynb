# %%
import sys
# !{sys.executable} -m pip install --upgrade --force-reinstall pydantic pydantic-core anthropic
# Out:
# Collecting pydantic
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting pydantic-core
#   Using cached pydantic_core-2.47.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting anthropic
#   Using cached anthropic-0.105.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core
#   Using cached pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Using cached docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Using cached jiter-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from anthropic)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Using cached certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached anthropic-0.105.2-py3-none-any.whl (837 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jiter-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (346 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached certifi-2026.5.20-py3-none-any.whl (134 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, anthropic
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: jiter
#     Found existing installation: jiter 0.15.0
#     Uninstalling jiter-0.15.0:
#       Successfully uninstalled jiter-0.15.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
#   Attempting uninstall: h110m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Found existing installation: h11 0.16.0━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Uninstalling h11-0.16.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#       Successfully uninstalled h11-0.16.0━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#   Attempting uninstall: docstring-parser━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Found existing installation: docstring_parser 0.18.0━━━━━━  3/16 [idna]
#     Uninstalling docstring_parser-0.18.0:━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#       Successfully uninstalled docstring_parser-0.18.0━━━━━━━━  3/16 [idna]
#   Attempting uninstall: distro━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Found existing installation: distro 1.9.0━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Uninstalling distro-1.9.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#       Successfully uninstalled distro-1.9.0━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#   Attempting uninstall: certifi━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Found existing installation: certifi 2026.5.20━━━━━━━━━━━━  3/16 [idna]
#     Uninstalling certifi-2026.5.20:━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#       Successfully uninstalled certifi-2026.5.20━━━━━━━━━━━━━━  3/16 [idna]
#   Attempting uninstall: annotated-types━━━━━━━━━━━━━━━━━━━━━━━  3/16 [idna]
#     Found existing installation: annotated-types 0.7.0━━━━━━━━━━━━  8/16 [annotated-types]
#     Uninstalling annotated-types-0.7.0:━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#       Successfully uninstalled annotated-types-0.7.0━━━━━━━━━━  8/16 [annotated-types]
#   Attempting uninstall: typing-inspection0m━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#     Found existing installation: typing-inspection 0.4.2━━━━━━  8/16 [annotated-types]
#     Uninstalling typing-inspection-0.4.2:0m━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#       Successfully uninstalled typing-inspection-0.4.2━━━━━━━━  8/16 [annotated-types]
#   Attempting uninstall: pydantic-corem━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#     Found existing installation: pydantic_core 2.46.4━━━━━━━━━  8/16 [annotated-types]
#     Uninstalling pydantic_core-2.46.4:━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#       Successfully uninstalled pydantic_core-2.46.4━━━━━━━━━━━  8/16 [annotated-types]
#   Attempting uninstall: httpcorem╺━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#     Found existing installation: httpcore 1.0.9━━━━━━━━━━━━━━━  8/16 [annotated-types]
#     Uninstalling httpcore-1.0.9:m╺━━━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#       Successfully uninstalled httpcore-1.0.9━━━━━━━━━━━━━━━━━  8/16 [annotated-types]
#   Attempting uninstall: anyio━━━━━━╸━━━━━━━━━━━━ 11/16 [httpcore]es]
#     Found existing installation: anyio 4.13.0━━━━━━━━━━━━ 11/16 [httpcore]
#     Uninstalling anyio-4.13.0:━╸━━━━━━━━━━━━ 11/16 [httpcore]
#       Successfully uninstalled anyio-4.13.00m━━━━━━━━━━━━ 11/16 [httpcore]
#   Attempting uninstall: pydantic━━━━━━╺━━━━━━━━━ 12/16 [anyio]
#     Found existing installation: pydantic 2.13.4━━━━━━━━━ 12/16 [anyio]
#     Uninstalling pydantic-2.13.4:━╺━━━━━━━━━ 12/16 [anyio]
#       Successfully uninstalled pydantic-2.13.40m━━━━━━━━━ 12/16 [anyio]
#   Attempting uninstall: httpx━━━━━━━━━━━╸━━━━━━━ 13/16 [pydantic]
#     Found existing installation: httpx 0.28.1╸━━━━━━━ 13/16 [pydantic]
#     Uninstalling httpx-0.28.1:━━━━━━╸━━━━━━━ 13/16 [pydantic]
#       Successfully uninstalled httpx-0.28.11m╸━━━━━━━ 13/16 [pydantic]
#   Attempting uninstall: anthropic━━━━━━━━━━╺━━━━ 14/16 [httpx]
#     Found existing installation: anthropic 0.105.2━━━━ 14/16 [httpx]
#     Uninstalling anthropic-0.105.2:━━━━━━━━━━╸━━ 15/16 [anthropic]
#       Successfully uninstalled anthropic-0.105.21m╸━━ 15/16 [anthropic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [anthropic]16 [anthropic]
# Successfully installed annotated-types-0.7.0 anthropic-0.105.2 anyio-4.13.0 certifi-2026.5.20 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jiter-0.15.0 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 typing-extensions-4.15.0 typing-inspection-0.4.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # loads .env from the same folder as your notebook

api_key = os.getenv("ANTHROPIC_API_KEY")

# %%
#create an API client
from anthropic import Anthropic
model = "claude-sonnet-4-5"

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

# %%
message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = [
        {
            "role": "user", "content": "What is the capital of Nigeria?"
        }
    ]
)

# %%
message.content[0].text
# Out:
# "The capital of Nigeria is **Abuja**.\n\nAbuja became the capital in 1991, replacing Lagos, which had been the capital since independence. Lagos remains Nigeria's largest city and commercial center, but Abuja was chosen as the new capital due to its more central location in the country."

# %%
def add_user_message(messages, text):
    user_message = {"role": "user" , "content": text}
    messages.append(user_message)
    
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant" , "content": text}
    messages.append(assistant_message)
    
def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages
    )
    return message.content[0].text

# %%
message.content
# Out:
# [TextBlock(citations=None, text='The capital of Nigeria is Abuja.', type='text')]

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "What is the capital of Nigeria?")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "What is the population of that city?")

# Get the follow-up response with full context
final_answer = chat(messages)

final_answer
# Out:
# "The population of Abuja is approximately 3-4 million people in the metropolitan area. According to recent estimates, the city proper has around 1.2-1.8 million residents, while the greater Abuja metropolitan area (which includes surrounding settlements) has over 3 million people.\n\nAbuja has been one of Africa's fastest-growing cities since becoming the capital, with its population continuing to increase as people migrate there for economic and governmental opportunities."

# %% [markdown]
# Chatbot

# %%
# make an initial list of messages
messages = []

# use a 'While True' loop to run the chatbot forever
while True:
    # get user input
    user_input = input("> ")
    print(">", user_input)
    
    # add user message to the list of messages
    add_user_message(messages, user_input)
    
    #call claude with the chat function
    answer = chat(messages)
    
    #add generated text to the list of messages
    add_assistant_message(messages, answer)
    
    # print the generated response
    print("---")
    print(answer)
    print("---")
    
    # add the assistant's response to the conversation
